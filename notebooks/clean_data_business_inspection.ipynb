# %%
import pandas as pd

# %%
business_attributes = pd.read_csv("clean_data_business/business_attributes.csv", dtype=str)
business_attributes.head()
# Out:
#               business_id          attr_key        attr_group attr_sub  \
# 0  Kq51_lGAgAigqmENITTr-A  AcceptsInsurance  AcceptsInsurance      NaN
# 1  E_kLUlU60fzoZYAOxbH_3w  AcceptsInsurance  AcceptsInsurance      NaN
# 2  M_THnNDHs29aylcK-JqS1A  AcceptsInsurance  AcceptsInsurance      NaN
# 3  t5tBd4p7BA7hNDitBUXxrw  AcceptsInsurance  AcceptsInsurance      NaN
# 4  2oxrOO3c9_mQmqM9kwEm9Q  AcceptsInsurance  AcceptsInsurance      NaN
#
#   attr_value_clean
# 0            False
# 1             True
# 2             True
# 3             True
# 4             True

# %%
business_category = pd.read_csv("clean_data_business/business_category.csv", dtype=str)
business_category.head()
# Out:
#               business_id                      category
# 0  Pns2l4eNsfO8kk83dixA6A                       Doctors
# 1  Pns2l4eNsfO8kk83dixA6A  Traditional Chinese Medicine
# 2  Pns2l4eNsfO8kk83dixA6A         Naturopathic/Holistic
# 3  Pns2l4eNsfO8kk83dixA6A                   Acupuncture
# 4  Pns2l4eNsfO8kk83dixA6A              Health & Medical

# %%
business_clean = pd.read_csv("clean_data_business/business_clean.csv", dtype=str)
business_clean.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code is_open  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101       0
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123       1
# 2             5255 E Broadway Blvd         Tucson    AZ       85711       0
# 3                      935 Race St   Philadelphia    PA       19107       1
# 4                    101 Walnut St     Green Lane    PA       18054       1
#
#      latitude     longitude review_count stars hours.Monday hours.Tuesday  \
# 0  34.4266787  -119.7111968            7   5.0          NaN           NaN
# ...

# %%
business_hour = pd.read_csv("clean_data_business/business_hour.csv", dtype=str)
business_hour.head()
# Out:
#               business_id weekday     hours
# 0  mpf3x-BjTdTEA3yCZrAYPw  Monday   0:0-0:0
# 1  tUFrWirKiKi_TAnsVWINQQ  Monday  8:0-22:0
# 2  MTSW4McQd7CbVtyjqoe9mw  Monday  7:0-20:0
# 3  CF33F8-E6oudUQ46HnavjQ  Monday   0:0-0:0
# 4  n_0UpQx1hsNbnPUSlodU8w  Monday   0:0-0:0

# %%
business_hours_wide = pd.read_csv("clean_data_business/business_hours_wide.csv", dtype=str)
business_hours_wide.head()
# Out:
#   hours.Monday hours.Tuesday hours.Wednesday hours.Thursday hours.Friday  \
# 0          NaN           NaN             NaN            NaN          NaN
# 1      0:0-0:0     8:0-18:30       8:0-18:30      8:0-18:30    8:0-18:30
# 2     8:0-22:0      8:0-22:0        8:0-22:0       8:0-22:0     8:0-23:0
# 3     7:0-20:0      7:0-20:0        7:0-20:0       7:0-20:0     7:0-21:0
# 4          NaN           NaN       14:0-22:0      16:0-22:0    12:0-22:0
#
#   hours.Saturday hours.Sunday             business_id
# 0            NaN          NaN  Pns2l4eNsfO8kk83dixA6A
# 1       8:0-14:0          NaN  mpf3x-BjTdTEA3yCZrAYPw
# 2       8:0-23:0     8:0-22:0  tUFrWirKiKi_TAnsVWINQQ
# 3       7:0-21:0     7:0-21:0  MTSW4McQd7CbVtyjqoe9mw
# 4      12:0-22:0    12:0-18:0  mWMc6_wTdE0EUBKIGXDVfA

# %%
business_parking = pd.read_csv("clean_data_business/business_parking.csv", dtype=str)
business_parking.head()
# Out:
#   parking.garage parking.street parking.validated parking.lot parking.valet  \
# 0            NaN            NaN               NaN         NaN           NaN
# 1            NaN            NaN               NaN         NaN           NaN
# 2          False          False             False        True         False
# 3          False           True             False       False         False
# 4            NaN            NaN               NaN        True         False
#
#               business_id
# 0  Pns2l4eNsfO8kk83dixA6A
# 1  mpf3x-BjTdTEA3yCZrAYPw
# 2  tUFrWirKiKi_TAnsVWINQQ
# 3  MTSW4McQd7CbVtyjqoe9mw
# 4  mWMc6_wTdE0EUBKIGXDVfA
